# %%
class Account:
   def init (self, acc_num, pin, balance=0.0):
      self.acc_num= acc_num
      self.pin= pin
      self.balance = float (balance)
      self.history = [] # List to track Live session history

class ATMSystem:
   def __init__(self):
      #Dictionary of pre-existing accounts self.accounts
      self.accounts = {
           "112233": Account("112233", "1234", 500.0),
           "445566": Account("445566", "5678", 1500.0)
      }
      self.log_file = "atm_logs.txt"

   def log_transaction(self, acc_num, message):
        with open(self.log_file, "a") as file:
            file.write(f"Account {acc_num}: {message}\n")

   def authenticate(self, acc_num, pin):
        if acc_num in self.accounts and self.accounts[acc_num].pin == pin:
            return self.accounts[acc_num]
        return None

   def start_atm(self, acc_num, pin):
        account = self.authenticate(acc_num, pin)

        if not account:
            print("Invalid Account Number or PIN.")
            return

        print(f"\nWelcome, Account Holder {acc_num}!")

        while True:
            print("\n1. Check Balance")
            print("2. Deposit")
            print("3. Withdraw")
            print("4. Exit")

            choice = input("Select an option (1-4): ")

            if choice == "1":
                print(f"Current Balance: ${account.balance:.2f}")

            elif choice == "2":
                amount = float(input("Enter deposit amount: "))

                if amount > 0:
                    account.balance += amount
                    msg = f"Deposited ${amount:.2f}"
                    account.history.append(msg)
                    self.log_transaction(acc_num, msg)
                    print("Success!")
                else:
                    print("Invalid amount.")

            elif choice == "3":
                amount = float(input("Enter withdrawal amount: "))

                if 0 < amount <= account.balance:
                    account.balance -= amount
                    msg = f"Withdrew ${amount:.2f}"
                    account.history.append(msg)
                    self.log_transaction(acc_num, msg)
                    print("Success!")
                else:
                    print("Insufficient funds or invalid amount.")

            elif choice == "4":
                print("Thank you for using our ATM. Goodbye!")
                break

            else:
                print("Invalid option selected.")


# ----- Demonstration Run -----
if __name__ == "_main_":
    atm = ATMSystem()

    # Example Account:
    # Account Number: 112233
    # PIN: 1234

    ac_no = input("Plz Enter the Account Number: ")
    pin = input("Enter the PIN: ")

    atm.start_atm(ac_no, pin)

# %%
class Account:
    def __init__(self, acc_num, pin, balance=0.0):
        self.acc_num = acc_num
        self.pin = pin
        self.balance = float(balance)
        self.history = []


class ATMSystem:
    def __init__(self):
        self.accounts = {
            "112233": Account("112233", "1234", 500.0),
            "445566": Account("445566", "5678", 1500.0)
        }
        self.log_file = "atm_logs.txt"

    def log_transaction(self, acc_num, message):
        with open(self.log_file, "a") as file:
            file.write(f"Account {acc_num}: {message}\n")

    def authenticate(self, acc_num, pin):
        if acc_num in self.accounts and self.accounts[acc_num].pin == pin:
            return self.accounts[acc_num]
        return None

    def start_atm(self, acc_num, pin):
        account = self.authenticate(acc_num, pin)

        if not account:
            print("Invalid Account Number or PIN.")
            return

        print(f"\nWelcome, Account Holder {acc_num}!")

        while True:
            print("\n1. Check Balance")
            print("2. Deposit")
            print("3. Withdraw")
            print("4. Exit")

            choice = input("Select an option (1-4): ")

            if choice == "1":
                print(f"Current Balance: ${account.balance:.2f}")

            elif choice == "2":
                try:
                    amount = float(input("Enter deposit amount: "))
                    if amount > 0:
                        account.balance += amount
                        msg = f"Deposited ${amount:.2f}"
                        account.history.append(msg)
                        self.log_transaction(acc_num, msg)
                        print("Success!")
                    else:
                        print("Invalid amount.")
                except ValueError:
                    print("Please enter a valid number.")

            elif choice == "3":
                try:
                    amount = float(input("Enter withdrawal amount: "))
                    if 0 < amount <= account.balance:
                        account.balance -= amount
                        msg = f"Withdrew ${amount:.2f}"
                        account.history.append(msg)
                        self.log_transaction(acc_num, msg)
                        print("Success!")
                    else:
                        print("Insufficient funds or invalid amount.")
                except ValueError:
                    print("Please enter a valid number.")

            elif choice == "4":
                print("Thank you for using our ATM. Goodbye!")
                break

            else:
                print("Invalid option selected.")


if __name__ == "__main__":
    atm = ATMSystem()

    ac_no = input("Please Enter the Account Number: ")
    pin = input("Enter the PIN: ")

    atm.start_atm(ac_no, pin)
# Out:
# Please Enter the Account Number:  112233
# Enter the PIN:  1234
# Welcome, Account Holder 112233!
#
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
